# %%
from pydrake.all import (
    StartMeshcat
    )
from time import sleep
from generate_models import Playground
from pydrake.systems.analysis import Simulator
from manipulation.utils import RenderDiagram
from robots import IIWA
import numpy as np
from planner import ActionExecutor, connect_to_the_world
from planner import *
from environment import MovableBody
from utils import choose_closest_heuristic

import multiprocessing as mp
import os.path
import time
from collections import OrderedDict
from typing import Dict

import numpy as np
import pydot
from IPython.display import SVG, display
from pydrake.common.value import AbstractValue
from pydrake.geometry import (
    Meshcat,
    MeshcatVisualizer,
    QueryObject,
    Rgba,
    Role,
    SceneGraph,
    Sphere,
    StartMeshcat,
)
from pydrake.geometry.optimization import (
    HPolyhedron,
    IrisInConfigurationSpace,
    IrisOptions,
    LoadIrisRegionsYamlFile,
    SaveIrisRegionsYamlFile,
)
from pydrake.math import RigidTransform, RollPitchYaw, RotationMatrix
from pydrake.multibody.inverse_kinematics import InverseKinematics
from pydrake.multibody.meshcat import JointSliders
from pydrake.multibody.parsing import PackageMap, Parser
from pydrake.multibody.plant import AddMultibodyPlantSceneGraph, MultibodyPlant
from pydrake.multibody.tree import Body
from pydrake.solvers import MathematicalProgram, Solve
from pydrake.systems.framework import DiagramBuilder, LeafSystem
from pydrake.visualization import AddDefaultVisualization, ModelVisualizer

from manipulation import running_as_notebook
from manipulation.utils import FindDataResource
from settings import GRIPPER_BASE_LINK

# from iris_utils import *
from settings import DEFAULT_WELDED_SCENARIO_URL
from package_utils import CustomConfigureParser

# %%
meshcat = StartMeshcat()
# Out:
# INFO:drake:Meshcat listening for connections at http://localhost:7000

# %%
from pydrake.geometry import GeometrySet, CollisionFilterDeclaration

def fixIiwaGripperCollisionWithObjectInGripper(scene_graph, body_name, context = None):
    # todo later maybe generalize this instead of copying it from utils?
    if context is None:
        filter_manager = scene_graph.collision_filter_manager()
    else:
        filter_manager = scene_graph.collision_filter_manager(context)
    inspector = scene_graph.model_inspector()
    iiwa = []
    exclude_bodies = []
    # print("body_name: ", body_name)
    for gid in inspector.GetGeometryIds(
            GeometrySet(inspector.GetAllGeometryIds()), Role.kProximity
    ):
        gid_name = inspector.GetName(inspector.GetFrameId(gid))

        # print("Gid Name: ", gid_name)
        # if "iiwa" in gid_name:
        #     link_name = gid_name.split("::")[1]
        #     # print("IIWA Link name: ", link_name)
        #     iiwa[link_name] = [gid]
        if "wsg" in gid_name:
            iiwa.append(gid)
            # print("name: ", inspector.GetName(gid))
            # link_name = gid_name.split("::")[1]
            # # print("wsg link name: ", link_name)
            # # print("WSG Link name: ", link_name)
            # iiwa[link_name] = [gid]
            # if len(iiwa[link_name]) > 0:
            #     iiwa[link_name].append(gid)            
        if body_name in gid_name:
            # print("Body name: ", body_name)
            exclude_bodies.append(gid)

    # print('exclude bodies:')
    # print(exclude_bodies)
    # for i in range(len(iiwa)-1):
    #     for j in range(i+1, len(iiwa)):
    #         # print("Equals: ", iiwa[i] == iiwa[j])

    def add_exclusion(set1, set2=None):
        print(len(set2))
        if set2 is None:
            filter_manager.Apply(
                CollisionFilterDeclaration().ExcludeWithin(GeometrySet(set1))
            )
        else:
            filter_manager.Apply(
                CollisionFilterDeclaration().ExcludeBetween(
                    GeometrySet(set1), GeometrySet(set2)
                )
            )

    # todo this excludes both hands. what if we want to exclude only one gripper?
    add_exclusion(exclude_bodies, iiwa)

# %%
## Setup IRIS

iris_filename = "my_iris_object_welded.yaml"
iris_regions = dict()
q = []

iris_options = IrisOptions()
iris_options.iteration_limit = 10
# increase num_collision_infeasible_samples to improve the (probabilistic)
# certificate of having no collisions.
iris_options.num_collision_infeasible_samples = 3
iris_options.require_sample_point_is_contained = True
iris_options.relative_termination_threshold = 0.01
iris_options.termination_threshold = -1

# Additional options for this notebook:

# If use_existing_regions_as_obstacles is True, then iris_regions will be
# shrunk by regions_as_obstacles_margin, and then passed to
# iris_options.configuration_obstacles.
use_existing_regions_as_obstacles = True
regions_as_obstacles_scale_factor = 0.95

# We can compute some regions in parallel.
num_parallel = mp.cpu_count()

# %%
# plant_context = iiwa.get_fresh_plant_context()
# q_init = iiwa.plant.GetPositions(plant_context)
# q_init

# %% [markdown]
# ## Helper functions

# %%
def ScaleHPolyhedron(hpoly, scale_factor):
    # Shift to the center.
    xc = hpoly.ChebyshevCenter()
    A = hpoly.A()
    b = hpoly.b() - A @ xc
    # Scale
    b = scale_factor * b
    # Shift back
    b = b + A @ xc
    return HPolyhedron(A, b)


def _CheckNonEmpty(region):
    prog = MathematicalProgram()
    x = prog.NewContinuousVariables(region.ambient_dimension())
    region.AddPointInSetConstraints(prog, x)
    result = Solve(prog)
    assert result.is_success()


def _CalcRegion(name, seed):
    builder = DiagramBuilder()
    plant, scene_graph = AddMultibodyPlantSceneGraph(builder, 0.0)
    LoadRobot(plant)
    fixIiwaGripperCollisionWithObjectInGripper(scene_graph, "thing_1", context = None)
    plant.Finalize()
    diagram = builder.Build()
    diagram_context = diagram.CreateDefaultContext()
    plant_context = plant.GetMyContextFromRoot(diagram_context)

    plant.SetPositions(plant_context, seed)
    if use_existing_regions_as_obstacles:
        iris_options.configuration_obstacles = [
            ScaleHPolyhedron(r, regions_as_obstacles_scale_factor)
            for k, r in iris_regions.items()
            if k != name
        ]
        for h in iris_options.configuration_obstacles:
            _CheckNonEmpty(h)
    else:
        iris_options.configuration_obstacles = None
    display(f"Computing region for seed: {name}")
    start_time = time.time()
    hpoly = IrisInConfigurationSpace(plant, plant_context, iris_options)
    display(
        f"Finished seed {name}; Computation time: {(time.time() - start_time):.2f} seconds"
    )

    _CheckNonEmpty(hpoly)
    reduced = hpoly.ReduceInequalities()
    _CheckNonEmpty(reduced)

    return reduced


def GenerateRegion(name, seed):
    global iris_regions
    iris_regions[name] = _CalcRegion(name, seed)
    SaveIrisRegionsYamlFile(f"{iris_filename}.autosave", iris_regions)


def GenerateRegions(seed_dict, verbose=True):
    if use_existing_regions_as_obstacles:
        # Then run serially
        for k, v in seed_dict.items():
            GenerateRegion(k, v)
        return

    loop_time = time.time()
    with mp.Pool(processes=num_parallel) as pool:
        new_regions = pool.starmap(_CalcRegion, [[k, v] for k, v in seed_dict.items()])

    if verbose:
        print("Loop time:", time.time() - loop_time)

    global iris_regions
    iris_regions.update(dict(list(zip(seed_dict.keys(), new_regions))))


def DrawRobot(query_object: QueryObject, meshcat_prefix: str, draw_world: bool = True):
    rgba = Rgba(0.7, 0.7, 0.7, 0.3)
    role = Role.kProximity
    # This is a minimal replication of the work done in MeshcatVisualizer.
    inspector = query_object.inspector()
    for frame_id in inspector.GetAllFrameIds():
        if frame_id == inspector.world_frame_id():
            if not draw_world:
                continue
            frame_path = meshcat_prefix
        else:
            frame_path = f"{meshcat_prefix}/{inspector.GetName(frame_id)}"
        frame_path.replace("::", "/")
        frame_has_any_geometry = False
        for geom_id in inspector.GetGeometries(frame_id, role):
            path = f"{frame_path}/{geom_id.get_value()}"
            path.replace("::", "/")
            meshcat.SetObject(path, inspector.GetShape(geom_id), rgba)
            meshcat.SetTransform(path, inspector.GetPoseInFrame(geom_id))
            frame_has_any_geometry = True

        if frame_has_any_geometry:
            X_WF = query_object.GetPoseInWorld(frame_id)
            meshcat.SetTransform(frame_path, X_WF)


def VisualizeRegion(region_name, num_to_draw=30, draw_illustration_role_once=True):
    """
    A simple hit-and-run-style idea for visualizing the IRIS regions:
    1. Start at the center. Pick a random direction and run to the boundary.
    2. Pick a new random direction; project it onto the current boundary, and run along it. Repeat
    """

    builder = DiagramBuilder()
    plant, scene_graph = AddMultibodyPlantSceneGraph(builder, time_step=0.0)
    LoadRobot(plant)
    plant.Finalize()
    if draw_illustration_role_once:
        MeshcatVisualizer.AddToBuilder(builder, scene_graph, meshcat)
    diagram = builder.Build()
    context = diagram.CreateDefaultContext()
    plant_context = plant.GetMyMutableContextFromRoot(context)
    scene_graph_context = scene_graph.GetMyContextFromRoot(context)

    global iris_regions
    region = iris_regions[region_name]

    q = region.ChebyshevCenter()
    plant.SetPositions(plant_context, q)
    diagram.ForcedPublish(context)

    query = scene_graph.get_query_output_port().Eval(scene_graph_context)
    DrawRobot(query, f"{region_name}/0", True)

    rng = np.random.default_rng()
    nq = plant.num_positions()
    prog = MathematicalProgram()
    qvar = prog.NewContinuousVariables(nq, "q")
    prog.AddLinearConstraint(region.A(), 0 * region.b() - np.inf, region.b(), qvar)
    cost = prog.AddLinearCost(np.ones((nq, 1)), qvar)

    for i in range(1, num_to_draw):
        direction = rng.standard_normal(nq)
        cost.evaluator().UpdateCoefficients(direction)

        result = Solve(prog)
        assert result.is_success()

        q = result.GetSolution(qvar)
        plant.SetPositions(plant_context, q)
        query = scene_graph.get_query_output_port().Eval(scene_graph_context)
        DrawRobot(query, f"{region_name}/{i}", False)


def VisualizeRegions():
    for k in iris_regions.keys():
        meshcat.Delete()
        VisualizeRegion(k)
        button_name = f"Visualizing {k}; Press for next region"
        meshcat.AddButton(button_name, "Enter")
        print("Press Enter to visualize the next region")
        while meshcat.GetButtonClicks(button_name) < 1:
            time.sleep(1.0)
        meshcat.DeleteButton(button_name)


# TODO(russt): See https://github.com/RobotLocomotion/drake/pull/19520
class PoseSelector(LeafSystem):
    def __init__(
        self,
        body_index=None,
    ):
        LeafSystem.__init__(self)
        self._body_index = body_index
        self.DeclareAbstractInputPort(
            "body_poses", AbstractValue.Make([RigidTransform()])
        )
        self.DeclareAbstractOutputPort(
            "pose",
            lambda: AbstractValue.Make(RigidTransform()),
            self.CalcOutput,
        )

    def CalcOutput(self, context, output):
        body_poses = self.get_input_port().Eval(context)
        output.set_value(body_poses[self._body_index])

# %%
def MyInverseKinematics(X_WE, plant=None, context=None):
    if not plant:
        plant = MultibodyPlant(0.0)
        LoadRobot(plant)
        plant.Finalize()
    if not context:
        context = plant.CreateDefaultContext()
    # E = ee_body.body_frame()
    E = plant.GetBodyByName("body").body_frame()

    ik = InverseKinematics(plant, context)

    ik.AddPositionConstraint(
        E, [0, 0, 0], plant.world_frame(), X_WE.translation(), X_WE.translation()
    )

    ik.AddOrientationConstraint(
        E, RotationMatrix(), plant.world_frame(), X_WE.rotation(), 0.001
    )

    prog = ik.get_mutable_prog()
    q = ik.q()

    q0 = plant.GetPositions(context)
    prog.AddQuadraticErrorCost(np.identity(len(q)), q0, q)
    prog.SetInitialGuess(q, q0)
    result = Solve(ik.prog())
    if not result.is_success():
        print("IK failed")
        return None
    plant.SetPositions(context, result.GetSolution(q))
    return result.GetSolution(q)

# %%
if os.path.isfile(iris_filename):
    iris_regions.update(LoadIrisRegionsYamlFile(iris_filename))
    print(f"Loaded iris regions from {iris_filename}.")
else:
    print(f"{iris_filename} not found. No previously computed regions were loaded.")
# Out:
# Loaded iris regions from my_iris_object_welded.yaml.

# %% [markdown]
# ## load robot

# %%
def CustomParser(plant):
    parser = Parser(plant)
    return CustomConfigureParser(parser)

def LoadRobot(plant: MultibodyPlant) -> Body:
    """Setup your plant, and return the body corresponding to your
    end-effector."""
    parser = CustomParser(plant)
    # parser = Parser(plant)

    models_id = parser.AddModelsFromUrl(DEFAULT_WELDED_SCENARIO_URL)
    
    # brick = parser.AddModelsFromUrl(
    #     "package://drake_models/manipulation_station/061_foam_brick.sdf"
    # )[0]
    # plant.WeldFrames(
    #     plant.world_frame(),
    #     plant.GetFrameByName("base_link", brick),
    #     RigidTransform([0.88, 0, 0.62]),
    # )
    gripper = plant.GetModelInstanceByName("wsg")
    end_effector_body = plant.GetBodyByName("body", gripper)

    # plant_context = plant.get

    return end_effector_body

# %%
# This is a handy way to test your model.
v = ModelVisualizer(meshcat=meshcat)
LoadRobot(v.parser().plant())
v.Run()
# Out:
# INFO:drake:Click 'Stop Running' or press Esc to quit

# %% [markdown]
# ## Collision geometry details

# %%
def CollisionGeometryReport():
    builder = DiagramBuilder()
    plant, scene_graph = AddMultibodyPlantSceneGraph(builder, time_step=0.0)
    LoadRobot(plant)
    # fixIiwaGripperCollisionWithObjectInGripper(scene_graph, "thing_1", context = None)
    plant.Finalize()
    diagram = builder.Build()
    context = diagram.CreateDefaultContext()
    plant_context = plant.GetMyContextFromRoot(context)
    plant: MultibodyPlant = plant # what's the point of this line?

    positions = plant.GetPositions(plant_context)
    positions[7] = -0.01062164
    positions[8] = 0.01063314
    plant.SetPositions(plant_context, positions)

    query_object = plant.get_geometry_query_input_port().Eval(plant_context)
    inspector = query_object.inspector()
    pairs = inspector.GetCollisionCandidates()
    print("Number of pairs: ", len(pairs))
    for geomA, geomB in pairs:
        frameA = inspector.GetFrameId(geomA)
        frameB = inspector.GetFrameId(geomB)
        # print(
        #     f"{inspector.GetName(geomA)} (in {inspector.GetName(frameA)}) + {inspector.GetName(geomB)} (in {inspector.GetName(frameB)})"
        # )

CollisionGeometryReport()

def CollisionGeometryReport():
    builder = DiagramBuilder()
    plant, scene_graph = AddMultibodyPlantSceneGraph(builder, time_step=0.0)
    LoadRobot(plant)
    fixIiwaGripperCollisionWithObjectInGripper(scene_graph, "thing_1", context = None)
    plant.Finalize()
    diagram = builder.Build()
    context = diagram.CreateDefaultContext()
    plant_context = plant.GetMyContextFromRoot(context)
    plant: MultibodyPlant = plant # what's the point of this line?

    positions = plant.GetPositions(plant_context)
    positions[7] = -0.01062164
    positions[8] = 0.01063314
    plant.SetPositions(plant_context, positions)

    query_object = plant.get_geometry_query_input_port().Eval(plant_context)
    inspector = query_object.inspector()
    pairs = inspector.GetCollisionCandidates()
    print("Number of pairs: ", len(pairs))
    for geomA, geomB in pairs:
        frameA = inspector.GetFrameId(geomA)
        frameB = inspector.GetFrameId(geomB)
        print(
            f"{inspector.GetName(geomA)} (in {inspector.GetName(frameA)}) + {inspector.GetName(geomB)} (in {inspector.GetName(frameB)})"
        )

CollisionGeometryReport()
# Out:
# Number of pairs:  231
# 5
# Number of pairs:  227
# wsg::collision (in wsg::right_finger) + shelves_2::bottom (in shelves_2::top_and_bottom)
# iiwa::iiwa_link_0_collision (in iiwa::iiwa_link_0) + iiwa::iiwa_link_2_collision (in iiwa::iiwa_link_2)
# iiwa::iiwa_link_1_collision (in iiwa::iiwa_link_1) + shelves_1::right_wall (in shelves_1::shelves_body)
# wsg::left_tip (in wsg::left_finger) + shelves_2::shelf_upper (in shelves_2::top_and_bottom)
# iiwa::iiwa_link_3_collision (in iiwa::iiwa_link_3) + shelves_2::top (in shelves_2::top_and_bottom)
# iiwa::iiwa_link_3_collision (in iiwa::iiwa_link_3) + wsg::collision (in wsg::left_finger)
# wsg::collision (in wsg::right_finger) + shelves_1::left_wall (in shelves_1::shelves_body)
# iiwa::iiwa_link_6_collision (in iiwa::iiwa_link_6) + shelves_1::left_wall (in shelves_1::shelves_body)
# iiwa::iiwa_link_3_collision (in iiwa::iiwa_link_3) + thing_1::brick_box (in thing_1::brick_center)
# iiwa::iiwa_link_4_collision (in iiwa::iiwa_link_4) + wsg::collision (in wsg::body)
# iiwa::iiwa_link_4_collision (in iiwa::iiwa_link_4) + shelves_2::shelf_lower (in shelves_2::top_and_bottom)
# iiwa::iiwa_link_2_collision (in iiwa::iiwa_link_2) + shelves_1::shelf_lower (in shelves_1::top_and_bottom)
# iiwa::iiwa_link_2_collision (in iiwa::iiwa_link_2) + shelves_2::right_wall (in shelves_2::shelves_body)
# wsg::collision (in wsg::left_finger) + shelves_2::shelf_upper (in shelves_2::top_and_bottom)
# iiwa::iiwa_link_1_collision (in iiwa::iiwa_link_1) + shelves_2::bottom (in shelves_2::top_and_bottom)
# iiwa::iiwa_link_1_collision (in iiwa::iiwa_link_1) + wsg::left_tip (in wsg::left_finger)
# wsg::collision (in wsg::body) + shelves_1::top (in shelves_1::top_and_bottom)
# iiwa::iiwa_link_1_collision (in iiwa::iiwa_link_1) + wsg::collision (in wsg::right_finger)
# iiwa::iiwa_link_7_collision (in iiwa::iiwa_link_7) + shelves_2::left_wall (in shelves_2::shelves_body)
# wsg::collision (in wsg::right_finger) + shelves_2::top (in shelves_2::top_and_bottom)
# iiwa::iiwa_link_1_collision (in iiwa::iiwa_link_1) + shelves_1::left_wall (in shelves_1::shelves_body)
# iiwa::iiwa_link_3_collision (in iiwa::iiwa_link_3) + wsg::collision (in wsg::body)
# iiwa::iiwa_link_3_collision (in iiwa::iiwa_link_3) + shelves_2::shelf_lower (in shelves_2::top_and_bottom)
# iiwa::iiwa_link_7_collision (in iiwa::iiwa_link_7) + wsg::right_tip (in wsg::right_finger)
# iiwa::iiwa_link_0_collision (in iiwa::iiwa_link_0) + iiwa::iiwa_link_6_collision (in iiwa::iiwa_link_6)
# iiwa::iiwa_link_7_collision (in iiwa::iiwa_link_7) + shelves_1::right_wall (in shelves_1::shelves_body)
# iiwa::iiwa_link_4_collision (in iiwa::iiwa_link_4) + shelves_2::shelf_upper (in shelves_2::top_and_bottom)
# iiwa::iiwa_link_1_collision (in iiwa::iiwa_link_1) + iiwa::iiwa_link_4_collision (in iiwa::iiwa_link_4)
# iiwa::iiwa_link_6_collision (in iiwa::iiwa_link_6) + shelves_1::bottom (in shelves_1::top_and_bottom)
# iiwa::iiwa_link_2_collision (in iiwa::iiwa_link_2) + shelves_1::shelf_upper (in shelves_1::top_and_bottom)
# wsg::left_tip (in wsg::left_finger) + shelves_1::bottom (in shelves_1::top_and_bottom)
# iiwa::iiwa_link_1_collision (in iiwa::iiwa_link_1) + shelves_2::top (in shelves_2::top_and_bottom)
# iiwa::iiwa_link_1_collision (in iiwa::iiwa_link_1) + wsg::collision (in wsg::left_finger)
# iiwa::iiwa_link_1_collision (in iiwa::iiwa_link_1) + thing_1::brick_box (in thing_1::brick_center)
# wsg::collision (in wsg::body) + shelves_1::shelf_lower (in shelves_1::top_and_bottom)
# wsg::collision (in wsg::body) + shelves_2::right_wall (in shelves_2::shelves_body)
# wsg::collision (in wsg::right_finger) + shelves_2::shelf_lower (in shelves_2::top_and_bottom)
# iiwa::iiwa_link_7_collision (in iiwa::iiwa_link_7) + shelves_2::bottom (in shelves_2::top_and_bottom)
# iiwa::iiwa_link_7_collision (in iiwa::iiwa_link_7) + wsg::left_tip (in wsg::left_finger)
# wsg::right_tip (in wsg::right_finger) + shelves_1::right_wall (in shelves_1::shelves_body)
# iiwa::iiwa_link_3_collision (in iiwa::iiwa_link_3) + shelves_2::shelf_upper (in shelves_2::top_and_bottom)
# iiwa::iiwa_link_4_collision (in iiwa::iiwa_link_4) + iiwa::iiwa_link_7_collision (in iiwa::iiwa_link_7)
# iiwa::iiwa_link_7_collision (in iiwa::iiwa_link_7) + wsg::collision (in wsg::right_finger)
# wsg::collision (in wsg::left_finger) + shelves_1::bottom (in shelves_1::top_and_bottom)
# iiwa::iiwa_link_6_collision (in iiwa::iiwa_link_6) + shelves_1::top (in shelves_1::top_and_bottom)
# iiwa::iiwa_link_5_collision (in iiwa::iiwa_link_5) + shelves_2::left_wall (in shelves_2::shelves_body)
# iiwa::iiwa_link_1_collision (in iiwa::iiwa_link_1) + wsg::collision (in wsg::body)
# wsg::left_tip (in wsg::left_finger) + shelves_1::top (in shelves_1::top_and_bottom)
# iiwa::iiwa_link_1_collision (in iiwa::iiwa_link_1) + shelves_2::shelf_lower (in shelves_2::top_and_bottom)
# iiwa::iiwa_link_5_collision (in iiwa::iiwa_link_5) + wsg::right_tip (in wsg::right_finger)
# wsg::right_tip (in wsg::right_finger) + shelves_2::bottom (in shelves_2::top_and_bottom)
# iiwa::iiwa_link_5_collision (in iiwa::iiwa_link_5) + shelves_1::right_wall (in shelves_1::shelves_body)
# wsg::collision (in wsg::body) + shelves_1::shelf_upper (in shelves_1::top_and_bottom)
# iiwa::iiwa_link_4_collision (in iiwa::iiwa_link_4) + shelves_1::bottom (in shelves_1::top_and_bottom)
# wsg::collision (in wsg::right_finger) + shelves_2::shelf_upper (in shelves_2::top_and_bottom)
# iiwa::iiwa_link_3_collision (in iiwa::iiwa_link_3) + iiwa::iiwa_link_7_collision (in iiwa::iiwa_link_7)
# iiwa::iiwa_link_7_collision (in iiwa::iiwa_link_7) + shelves_2::top (in shelves_2::top_and_bottom)
# iiwa::iiwa_link_7_collision (in iiwa::iiwa_link_7) + wsg::collision (in wsg::left_finger)
# wsg::right_tip (in wsg::right_finger) + shelves_1::left_wall (in shelves_1::shelves_body)
# wsg::collision (in wsg::left_finger) + shelves_1::top (in shelves_1::top_and_bottom)
# iiwa::iiwa_link_1_collision (in iiwa::iiwa_link_1) + iiwa::iiwa_link_3_collision (in iiwa::iiwa_link_3)
# iiwa::iiwa_link_6_collision (in iiwa::iiwa_link_6) + shelves_1::shelf_lower (in shelves_1::top_and_bottom)
# iiwa::iiwa_link_6_collision (in iiwa::iiwa_link_6) + shelves_2::right_wall (in shelves_2::shelves_body)
# iiwa::iiwa_link_5_collision (in iiwa::iiwa_link_5) + shelves_2::bottom (in shelves_2::top_and_bottom)
# wsg::collision (in wsg::body) + shelves_1::bottom (in shelves_1::top_and_bottom)
# iiwa::iiwa_link_5_collision (in iiwa::iiwa_link_5) + wsg::left_tip (in wsg::left_finger)
# wsg::left_tip (in wsg::left_finger) + shelves_1::shelf_lower (in shelves_1::top_and_bottom)
# iiwa::iiwa_link_1_collision (in iiwa::iiwa_link_1) + shelves_2::shelf_upper (in shelves_2::top_and_bottom)
# iiwa::iiwa_link_3_collision (in iiwa::iiwa_link_3) + shelves_1::bottom (in shelves_1::top_and_bottom)
# iiwa::iiwa_link_5_collision (in iiwa::iiwa_link_5) + wsg::collision (in wsg::right_finger)
# wsg::left_tip (in wsg::left_finger) + shelves_2::right_wall (in shelves_2::shelves_body)
# wsg::right_tip (in wsg::right_finger) + shelves_2::top (in shelves_2::top_and_bottom)
# iiwa::iiwa_link_5_collision (in iiwa::iiwa_link_5) + shelves_1::left_wall (in shelves_1::shelves_body)
# iiwa::iiwa_link_4_collision (in iiwa::iiwa_link_4) + shelves_1::top (in shelves_1::top_and_bottom)
# shelves_1::left_wall (in shelves_1::shelves_body) + thing_1::brick_box (in thing_1::brick_center)
# iiwa::iiwa_link_7_collision (in iiwa::iiwa_link_7) + shelves_2::shelf_lower (in shelves_2::top_and_bottom)
# iiwa::iiwa_link_4_collision (in iiwa::iiwa_link_4) + iiwa::iiwa_link_6_collision (in iiwa::iiwa_link_6)
# wsg::collision (in wsg::left_finger) + shelves_1::shelf_lower (in shelves_1::top_and_bottom)
# wsg::collision (in wsg::left_finger) + shelves_2::right_wall (in shelves_2::shelves_body)
# iiwa::iiwa_link_6_collision (in iiwa::iiwa_link_6) + shelves_1::shelf_upper (in shelves_1::top_and_bottom)
# wsg::collision (in wsg::right_finger) + shelves_1::bottom (in shelves_1::top_and_bottom)
# iiwa::iiwa_link_1_collision (in iiwa::iiwa_link_1) + iiwa::iiwa_link_7_collision (in iiwa::iiwa_link_7)
# iiwa::iiwa_link_5_collision (in iiwa::iiwa_link_5) + shelves_2::top (in shelves_2::top_and_bottom)
# iiwa::iiwa_link_5_collision (in iiwa::iiwa_link_5) + wsg::collision (in wsg::left_finger)
# wsg::left_tip (in wsg::left_finger) + shelves_1::shelf_upper (in shelves_1::top_and_bottom)
# iiwa::iiwa_link_5_collision (in iiwa::iiwa_link_5) + thing_1::brick_box (in thing_1::brick_center)
# iiwa::iiwa_link_2_collision (in iiwa::iiwa_link_2) + iiwa::iiwa_link_5_collision (in iiwa::iiwa_link_5)
# iiwa::iiwa_link_3_collision (in iiwa::iiwa_link_3) + shelves_1::top (in shelves_1::top_and_bottom)
# wsg::left_tip (in wsg::left_finger) + shelves_2::left_wall (in shelves_2::shelves_body)
# iiwa::iiwa_link_2_collision (in iiwa::iiwa_link_2) + shelves_2::left_wall (in shelves_2::shelves_body)
# shelves_1::shelf_upper (in shelves_1::top_and_bottom) + thing_1::brick_box (in thing_1::brick_center)
# wsg::right_tip (in wsg::right_finger) + shelves_2::shelf_lower (in shelves_2::top_and_bottom)
# iiwa::iiwa_link_3_collision (in iiwa::iiwa_link_3) + iiwa::iiwa_link_6_collision (in iiwa::iiwa_link_6)
# iiwa::iiwa_link_4_collision (in iiwa::iiwa_link_4) + shelves_1::shelf_lower (in shelves_1::top_and_bottom)
# iiwa::iiwa_link_4_collision (in iiwa::iiwa_link_4) + shelves_2::right_wall (in shelves_2::shelves_body)
# iiwa::iiwa_link_2_collision (in iiwa::iiwa_link_2) + wsg::right_tip (in wsg::right_finger)
# iiwa::iiwa_link_7_collision (in iiwa::iiwa_link_7) + shelves_2::shelf_upper (in shelves_2::top_and_bottom)
# iiwa::iiwa_link_2_collision (in iiwa::iiwa_link_2) + shelves_1::right_wall (in shelves_1::shelves_body)
# wsg::collision (in wsg::left_finger) + shelves_1::shelf_upper (in shelves_1::top_and_bottom)
# iiwa::iiwa_link_1_collision (in iiwa::iiwa_link_1) + shelves_1::bottom (in shelves_1::top_and_bottom)
# wsg::collision (in wsg::left_finger) + shelves_2::left_wall (in shelves_2::shelves_body)
# iiwa::iiwa_link_7_collision (in iiwa::iiwa_link_7) + shelves_1::left_wall (in shelves_1::shelves_body)
# iiwa::iiwa_link_5_collision (in iiwa::iiwa_link_5) + wsg::collision (in wsg::body)
# wsg::collision (in wsg::right_finger) + shelves_1::top (in shelves_1::top_and_bottom)
# iiwa::iiwa_link_5_collision (in iiwa::iiwa_link_5) + shelves_2::shelf_lower (in shelves_2::top_and_bottom)
# iiwa::iiwa_link_3_collision (in iiwa::iiwa_link_3) + shelves_1::shelf_lower (in shelves_1::top_and_bottom)
# iiwa::iiwa_link_3_collision (in iiwa::iiwa_link_3) + shelves_2::right_wall (in shelves_2::shelves_body)
# wsg::right_tip (in wsg::right_finger) + shelves_2::shelf_upper (in shelves_2::top_and_bottom)
# iiwa::iiwa_link_2_collision (in iiwa::iiwa_link_2) + shelves_2::bottom (in shelves_2::top_and_bottom)
# iiwa::iiwa_link_4_collision (in iiwa::iiwa_link_4) + shelves_1::shelf_upper (in shelves_1::top_and_bottom)
# iiwa::iiwa_link_2_collision (in iiwa::iiwa_link_2) + wsg::left_tip (in wsg::left_finger)
# iiwa::iiwa_link_2_collision (in iiwa::iiwa_link_2) + wsg::collision (in wsg::right_finger)
# wsg::collision (in wsg::body) + shelves_2::left_wall (in shelves_2::shelves_body)
# iiwa::iiwa_link_2_collision (in iiwa::iiwa_link_2) + shelves_1::left_wall (in shelves_1::shelves_body)
# iiwa::iiwa_link_0_collision (in iiwa::iiwa_link_0) + iiwa::iiwa_link_5_collision (in iiwa::iiwa_link_5)
# iiwa::iiwa_link_1_collision (in iiwa::iiwa_link_1) + shelves_1::top (in shelves_1::top_and_bottom)
# iiwa::iiwa_link_1_collision (in iiwa::iiwa_link_1) + iiwa::iiwa_link_6_collision (in iiwa::iiwa_link_6)
# wsg::collision (in wsg::body) + shelves_1::right_wall (in shelves_1::shelves_body)
# wsg::collision (in wsg::right_finger) + shelves_1::shelf_lower (in shelves_1::top_and_bottom)
# iiwa::iiwa_link_5_collision (in iiwa::iiwa_link_5) + shelves_2::shelf_upper (in shelves_2::top_and_bottom)
# iiwa::iiwa_link_0_collision (in iiwa::iiwa_link_0) + wsg::right_tip (in wsg::right_finger)
# iiwa::iiwa_link_2_collision (in iiwa::iiwa_link_2) + iiwa::iiwa_link_4_collision (in iiwa::iiwa_link_4)
# iiwa::iiwa_link_7_collision (in iiwa::iiwa_link_7) + shelves_1::bottom (in shelves_1::top_and_bottom)
# wsg::collision (in wsg::right_finger) + shelves_2::right_wall (in shelves_2::shelves_body)
# iiwa::iiwa_link_3_collision (in iiwa::iiwa_link_3) + shelves_1::shelf_upper (in shelves_1::top_and_bottom)
# shelves_1::right_wall (in shelves_1::shelves_body) + thing_1::brick_box (in thing_1::brick_center)
# iiwa::iiwa_link_2_collision (in iiwa::iiwa_link_2) + shelves_2::top (in shelves_2::top_and_bottom)
# iiwa::iiwa_link_2_collision (in iiwa::iiwa_link_2) + wsg::collision (in wsg::left_finger)
# iiwa::iiwa_link_2_collision (in iiwa::iiwa_link_2) + thing_1::brick_box (in thing_1::brick_center)
# shelves_1::top (in shelves_1::top_and_bottom) + thing_1::brick_box (in thing_1::brick_center)
# shelves_2::right_wall (in shelves_2::shelves_body) + thing_1::brick_box (in thing_1::brick_center)
# wsg::collision (in wsg::body) + shelves_2::bottom (in shelves_2::top_and_bottom)
# iiwa::iiwa_link_1_collision (in iiwa::iiwa_link_1) + shelves_1::shelf_lower (in shelves_1::top_and_bottom)
# iiwa::iiwa_link_1_collision (in iiwa::iiwa_link_1) + shelves_2::right_wall (in shelves_2::shelves_body)
# iiwa::iiwa_link_5_collision (in iiwa::iiwa_link_5) + iiwa::iiwa_link_7_collision (in iiwa::iiwa_link_7)
# wsg::right_tip (in wsg::right_finger) + shelves_1::bottom (in shelves_1::top_and_bottom)
# iiwa::iiwa_link_0_collision (in iiwa::iiwa_link_0) + wsg::left_tip (in wsg::left_finger)
# wsg::collision (in wsg::right_finger) + shelves_1::shelf_upper (in shelves_1::top_and_bottom)
# iiwa::iiwa_link_7_collision (in iiwa::iiwa_link_7) + shelves_1::top (in shelves_1::top_and_bottom)
# iiwa::iiwa_link_0_collision (in iiwa::iiwa_link_0) + wsg::collision (in wsg::right_finger)
# wsg::collision (in wsg::right_finger) + shelves_2::left_wall (in shelves_2::shelves_body)
# iiwa::iiwa_link_6_collision (in iiwa::iiwa_link_6) + shelves_2::left_wall (in shelves_2::shelves_body)
# shelves_1::shelf_lower (in shelves_1::top_and_bottom) + thing_1::brick_box (in thing_1::brick_center)
# shelves_2::left_wall (in shelves_2::shelves_body) + thing_1::brick_box (in thing_1::brick_center)
# iiwa::iiwa_link_2_collision (in iiwa::iiwa_link_2) + wsg::collision (in wsg::body)
# shelves_2::shelf_lower (in shelves_2::top_and_bottom) + thing_1::brick_box (in thing_1::brick_center)
# iiwa::iiwa_link_2_collision (in iiwa::iiwa_link_2) + shelves_2::shelf_lower (in shelves_2::top_and_bottom)
# iiwa::iiwa_link_6_collision (in iiwa::iiwa_link_6) + wsg::right_tip (in wsg::right_finger)
# iiwa::iiwa_link_6_collision (in iiwa::iiwa_link_6) + shelves_1::right_wall (in shelves_1::shelves_body)
# iiwa::iiwa_link_5_collision (in iiwa::iiwa_link_5) + shelves_1::bottom (in shelves_1::top_and_bottom)
# iiwa::iiwa_link_0_collision (in iiwa::iiwa_link_0) + iiwa::iiwa_link_4_collision (in iiwa::iiwa_link_4)
# wsg::left_tip (in wsg::left_finger) + wsg::right_tip (in wsg::right_finger)
# wsg::collision (in wsg::body) + shelves_2::top (in shelves_2::top_and_bottom)
# iiwa::iiwa_link_1_collision (in iiwa::iiwa_link_1) + shelves_1::shelf_upper (in shelves_1::top_and_bottom)
# wsg::left_tip (in wsg::left_finger) + shelves_1::right_wall (in shelves_1::shelves_body)
# wsg::right_tip (in wsg::right_finger) + shelves_1::top (in shelves_1::top_and_bottom)
# shelves_2::shelf_upper (in shelves_2::top_and_bottom) + thing_1::brick_box (in thing_1::brick_center)
# iiwa::iiwa_link_0_collision (in iiwa::iiwa_link_0) + wsg::collision (in wsg::left_finger)
# iiwa::iiwa_link_0_collision (in iiwa::iiwa_link_0) + thing_1::brick_box (in thing_1::brick_center)
# iiwa::iiwa_link_7_collision (in iiwa::iiwa_link_7) + shelves_1::shelf_lower (in shelves_1::top_and_bottom)
# iiwa::iiwa_link_7_collision (in iiwa::iiwa_link_7) + shelves_2::right_wall (in shelves_2::shelves_body)
# wsg::collision (in wsg::left_finger) + wsg::right_tip (in wsg::right_finger)
# iiwa::iiwa_link_6_collision (in iiwa::iiwa_link_6) + shelves_2::bottom (in shelves_2::top_and_bottom)
# iiwa::iiwa_link_6_collision (in iiwa::iiwa_link_6) + wsg::left_tip (in wsg::left_finger)
# wsg::collision (in wsg::left_finger) + shelves_1::right_wall (in shelves_1::shelves_body)
# iiwa::iiwa_link_2_collision (in iiwa::iiwa_link_2) + shelves_2::shelf_upper (in shelves_2::top_and_bottom)
# iiwa::iiwa_link_6_collision (in iiwa::iiwa_link_6) + wsg::collision (in wsg::right_finger)
# wsg::left_tip (in wsg::left_finger) + shelves_2::bottom (in shelves_2::top_and_bottom)
# iiwa::iiwa_link_5_collision (in iiwa::iiwa_link_5) + shelves_1::top (in shelves_1::top_and_bottom)
# iiwa::iiwa_link_4_collision (in iiwa::iiwa_link_4) + shelves_2::left_wall (in shelves_2::shelves_body)
# wsg::left_tip (in wsg::left_finger) + wsg::collision (in wsg::right_finger)
# wsg::collision (in wsg::body) + shelves_2::shelf_lower (in shelves_2::top_and_bottom)
# wsg::left_tip (in wsg::left_finger) + shelves_1::left_wall (in shelves_1::shelves_body)
# iiwa::iiwa_link_0_collision (in iiwa::iiwa_link_0) + wsg::collision (in wsg::body)
# wsg::right_tip (in wsg::right_finger) + shelves_1::shelf_lower (in shelves_1::top_and_bottom)
# iiwa::iiwa_link_4_collision (in iiwa::iiwa_link_4) + wsg::right_tip (in wsg::right_finger)
# wsg::right_tip (in wsg::right_finger) + shelves_2::right_wall (in shelves_2::shelves_body)
# wsg::collision (in wsg::left_finger) + shelves_2::bottom (in shelves_2::top_and_bottom)
# iiwa::iiwa_link_4_collision (in iiwa::iiwa_link_4) + shelves_1::right_wall (in shelves_1::shelves_body)
# iiwa::iiwa_link_7_collision (in iiwa::iiwa_link_7) + shelves_1::shelf_upper (in shelves_1::top_and_bottom)
# iiwa::iiwa_link_2_collision (in iiwa::iiwa_link_2) + iiwa::iiwa_link_7_collision (in iiwa::iiwa_link_7)
# wsg::collision (in wsg::left_finger) + wsg::collision (in wsg::right_finger)
# iiwa::iiwa_link_6_collision (in iiwa::iiwa_link_6) + shelves_2::top (in shelves_2::top_and_bottom)
# iiwa::iiwa_link_6_collision (in iiwa::iiwa_link_6) + wsg::collision (in wsg::left_finger)
# wsg::collision (in wsg::left_finger) + shelves_1::left_wall (in shelves_1::shelves_body)
# iiwa::iiwa_link_6_collision (in iiwa::iiwa_link_6) + thing_1::brick_box (in thing_1::brick_center)
# iiwa::iiwa_link_3_collision (in iiwa::iiwa_link_3) + iiwa::iiwa_link_5_collision (in iiwa::iiwa_link_5)
# shelves_1::bottom (in shelves_1::top_and_bottom) + thing_1::brick_box (in thing_1::brick_center)
# iiwa::iiwa_link_3_collision (in iiwa::iiwa_link_3) + shelves_2::left_wall (in shelves_2::shelves_body)
# iiwa::iiwa_link_0_collision (in iiwa::iiwa_link_0) + iiwa::iiwa_link_3_collision (in iiwa::iiwa_link_3)
# wsg::left_tip (in wsg::left_finger) + shelves_2::top (in shelves_2::top_and_bottom)
# iiwa::iiwa_link_5_collision (in iiwa::iiwa_link_5) + shelves_1::shelf_lower (in shelves_1::top_and_bottom)
# shelves_2::bottom (in shelves_2::top_and_bottom) + thing_1::brick_box (in thing_1::brick_center)
# iiwa::iiwa_link_5_collision (in iiwa::iiwa_link_5) + shelves_2::right_wall (in shelves_2::shelves_body)
# iiwa::iiwa_link_3_collision (in iiwa::iiwa_link_3) + wsg::right_tip (in wsg::right_finger)
# wsg::collision (in wsg::body) + shelves_2::shelf_upper (in shelves_2::top_and_bottom)
# iiwa::iiwa_link_4_collision (in iiwa::iiwa_link_4) + shelves_2::bottom (in shelves_2::top_and_bottom)
# iiwa::iiwa_link_4_collision (in iiwa::iiwa_link_4) + wsg::left_tip (in wsg::left_finger)
# iiwa::iiwa_link_3_collision (in iiwa::iiwa_link_3) + shelves_1::right_wall (in shelves_1::shelves_body)
# wsg::right_tip (in wsg::right_finger) + shelves_1::shelf_upper (in shelves_1::top_and_bottom)
# iiwa::iiwa_link_2_collision (in iiwa::iiwa_link_2) + shelves_1::bottom (in shelves_1::top_and_bottom)
# iiwa::iiwa_link_4_collision (in iiwa::iiwa_link_4) + wsg::collision (in wsg::right_finger)
# wsg::right_tip (in wsg::right_finger) + shelves_2::left_wall (in shelves_2::shelves_body)
# wsg::collision (in wsg::left_finger) + shelves_2::top (in shelves_2::top_and_bottom)
# iiwa::iiwa_link_4_collision (in iiwa::iiwa_link_4) + shelves_1::left_wall (in shelves_1::shelves_body)
# wsg::collision (in wsg::body) + shelves_1::left_wall (in shelves_1::shelves_body)
# iiwa::iiwa_link_6_collision (in iiwa::iiwa_link_6) + wsg::collision (in wsg::body)
# shelves_2::top (in shelves_2::top_and_bottom) + thing_1::brick_box (in thing_1::brick_center)
# iiwa::iiwa_link_6_collision (in iiwa::iiwa_link_6) + shelves_2::shelf_lower (in shelves_2::top_and_bottom)
# wsg::left_tip (in wsg::left_finger) + shelves_2::shelf_lower (in shelves_2::top_and_bottom)
# iiwa::iiwa_link_3_collision (in iiwa::iiwa_link_3) + shelves_2::bottom (in shelves_2::top_and_bottom)
# iiwa::iiwa_link_5_collision (in iiwa::iiwa_link_5) + shelves_1::shelf_upper (in shelves_1::top_and_bottom)
# iiwa::iiwa_link_3_collision (in iiwa::iiwa_link_3) + wsg::left_tip (in wsg::left_finger)
# wsg::collision (in wsg::right_finger) + shelves_1::right_wall (in shelves_1::shelves_body)
# iiwa::iiwa_link_0_collision (in iiwa::iiwa_link_0) + iiwa::iiwa_link_7_collision (in iiwa::iiwa_link_7)
# iiwa::iiwa_link_3_collision (in iiwa::iiwa_link_3) + wsg::collision (in wsg::right_finger)
# iiwa::iiwa_link_4_collision (in iiwa::iiwa_link_4) + shelves_2::top (in shelves_2::top_and_bottom)
# iiwa::iiwa_link_4_collision (in iiwa::iiwa_link_4) + wsg::collision (in wsg::left_finger)
# iiwa::iiwa_link_3_collision (in iiwa::iiwa_link_3) + shelves_1::left_wall (in shelves_1::shelves_body)
# iiwa::iiwa_link_4_collision (in iiwa::iiwa_link_4) + thing_1::brick_box (in thing_1::brick_center)
# iiwa::iiwa_link_1_collision (in iiwa::iiwa_link_1) + iiwa::iiwa_link_5_collision (in iiwa::iiwa_link_5)
# iiwa::iiwa_link_2_collision (in iiwa::iiwa_link_2) + shelves_1::top (in shelves_1::top_and_bottom)
# iiwa::iiwa_link_1_collision (in iiwa::iiwa_link_1) + shelves_2::left_wall (in shelves_2::shelves_body)
# wsg::collision (in wsg::left_finger) + shelves_2::shelf_lower (in shelves_2::top_and_bottom)
# iiwa::iiwa_link_2_collision (in iiwa::iiwa_link_2) + iiwa::iiwa_link_6_collision (in iiwa::iiwa_link_6)
# iiwa::iiwa_link_6_collision (in iiwa::iiwa_link_6) + shelves_2::shelf_upper (in shelves_2::top_and_bottom)
# iiwa::iiwa_link_1_collision (in iiwa::iiwa_link_1) + wsg::right_tip (in wsg::right_finger)

# %% [markdown]
# ## Run IRIS on manually-specified seeds

# %%
seeds = OrderedDict()
seeds["Start MoveToDeliver"] = np.array([-3.14203235e-01, 3.90712230e-01, 4.51960051e-01,
                                          -1.41120590e+00, -2.66424569e+00, 1.93009670e-01, 
                                          -6.67236596e-01, -0.01062164, 0.01063314])

seeds["End MoveToDeliver"] = np.array([-1.256648681160374, -0.42877396095962583, -1.1408169427411972, 
                                    -1.179779654371061, -1.3890241125896183, 0.7543578588148786, 
                                    -2.3128262167745812, -0.01062164, 0.01063314])
# seeds["Top Rack Shelve 1"] = np.array([0.8577218127779863, 1.0667040654704312, 1.33937485889043,
#                                     1.4461052605134126, 2.3363107715669296, -0.7493105522005948,
#                                     -1.1611574898891013, -0.05, 0.05])

# iris_regions = dict()
# GenerateRegions(seeds)

# %%
p0 = np.array([-0.5, 0.0, 0.67])
# p0 = np.array([-0.50, 0.0, 0.67])
R0 = RotationMatrix(np.array([[0, 1, 0], [-1, 0, 0], [0, 0, 1]]).T)
X_WGoal = RigidTransform(R0, p0)
# q = MyInverseKinematics(X_WGoal)
q = np.array([1.29198967, 0.48877053, 2.18207324, 
              -1.89026996, 1.18724797, -0.32679275,
              1.52868192, -0.01062164, 0.01063314])
# print(q)
GenerateRegion("End position 2", q)
# Out:
# 5
# 'Computing region for seed: End position 2'
# INFO:drake:IrisInConfigurationSpace iteration 0
# INFO:drake:IrisInConfigurationSpace iteration 1
# INFO:drake:IrisInConfigurationSpace iteration 2
# INFO:drake:IrisInConfigurationSpace iteration 3
# INFO:drake:IrisInConfigurationSpace iteration 4
# INFO:drake:IrisInConfigurationSpace iteration 5
# INFO:drake: Checking shelves_2::top against thing_1::brick_box has already required 30 counter-example searches; still searching...
# INFO:drake: Finished checking shelves_2::top against thing_1::brick_box after 35 counter-example searches.
# INFO:drake:IrisInConfigurationSpace iteration 6
# INFO:drake: Checking shelves_2::top against thing_1::brick_box has already required 30 counter-example searches; still searching...
# INFO:drake: Finished checking shelves_2::top against thing_1::brick_box after 36 counter-example searches.
# INFO:drake:IrisInConfigurationSpace iteration 7
# INFO:drake:IrisInConfigurationSpace iteration 8
# INFO:drake:IrisInConfigurationSpace iteration 9
# INFO:drake:IrisInConfigurationSpace: Terminating because the iteration limit 10 has been reached.
# 'Finished seed End position 2; Computation time: 234.16 seconds'

# %% [markdown]
# ## End effector teleop

# %%
from collections import namedtuple
from copy import copy

from pydrake.all import Context, Meshcat, MeshcatPoseSliders, SceneGraph

RpyXyz = namedtuple("RpyXyz", ("roll", "pitch", "yaw", "x", "y", "z"))


# Creates an indicator "light" (a colored sphere in the workspace)
# TODO(russt): use meshcat.SetProperty(path, "color", rgba) instead
def IrisIndicator(
    scene_graph: SceneGraph,
    scene_graph_context: Context,
    meshcat: Meshcat,
    iris_regions: Dict[str, HPolyhedron],
    p_WIndicator: list,
):
    radius = 0.1

    meshcat.SetTransform("iris_indicator", RigidTransform(p_WIndicator))

    query_object = scene_graph.get_query_output_port().Eval(scene_graph_context)
    has_collisions = query_object.HasCollisions()
    if has_collisions:
        meshcat.SetObject("iris_indicator", Sphere(radius), Rgba(1, 0, 0, 1))

    in_any_region = False
    for r in iris_regions.values():
        if r.PointInSet(q):
            if has_collisions:
                print("You found a counter-example!")
                # TODO(russt): Automatically shrink the iris region.
            elif not in_any_region:
                in_any_region = True
                meshcat.SetObject("iris_indicator", Sphere(radius), Rgba(0, 1, 0, 1))

    if not has_collisions and not in_any_region:
        meshcat.SetObject("iris_indicator", Sphere(radius), Rgba(0.5, 0.5, 0.5, 1))


def EndEffectorTeleop():
    meshcat.Delete()
    meshcat.DeleteAddedControls()

    builder = DiagramBuilder()
    plant, scene_graph = AddMultibodyPlantSceneGraph(builder, 0.0)
    ee_body = LoadRobot(plant)
    plant.Finalize()

    # Set up teleop widgets.
    sliders = builder.AddSystem(
        MeshcatPoseSliders(
            meshcat,
            lower_limit=RpyXyz(roll=0, pitch=-0.5, yaw=-np.pi, x=-0.6, y=-0.8, z=0.0),
            upper_limit=RpyXyz(
                roll=2 * np.pi, pitch=np.pi, yaw=np.pi, x=0.8, y=0.3, z=1.1
            ),
        )
    )
    print(
        """
Control the end-effector position/orientation with the sliders or the keyboard:
  ┌───────┬┬───────┬┬───────┐      ┌───────┬┬───────┬┬───────┐
  │   Q   ││   W   ││   E   │      │   U   ││   I   ││   O   │
  │ roll- ││ pitch+││ roll+ │      │   z-  ││   y+  ││   z+  │
  ├───────┼┼───────┼┼───────┤      ├───────┼┼───────┼┼───────┤
  ├───────┼┼───────┼┼───────┤      ├───────┼┼───────┼┼───────┤
  │   A   ││   S   ││   D   │      │   J   ││   K   ││   L   │
  │  yaw- ││ pitch-││  yaw+ │      │   x-  ││   y-  ││   x+  │
  └───────┴┴───────┴┴───────┘      └───────┴┴───────┴┴───────┘
"""
    )

    AddDefaultVisualization(builder, meshcat)

    diagram = builder.Build()
    context = diagram.CreateDefaultContext()
    plant_context = plant.GetMyMutableContextFromRoot(context)
    scene_graph_context = scene_graph.GetMyContextFromRoot(context)
    sliders_context = sliders.GetMyContextFromRoot(context)

    global q
    if len(q) == 0:
        q = plant.GetPositions(plant_context)
    plant.SetPositions(plant_context, q)
    X_WE = plant.EvalBodyPoseInWorld(plant_context, ee_body)
    sliders.SetPose(X_WE)

    iris_button_name = "Compute new IRIS region"
    meshcat.AddButton(iris_button_name)
    iris_button_clicks = 0

    stop_button_name = "Stop End Effector Teleop"
    print(
        f"Press the '{stop_button_name}' button in Meshcat to continue or press 'Escape'"
    )
    meshcat.AddButton(stop_button_name, "Escape")

    diagram.ForcedPublish(context)
    if not running_as_notebook:
        return

    while meshcat.GetButtonClicks(stop_button_name) < 1:
        # Check if the sliders have changed.
        new_X_WE = copy(sliders.get_output_port().Eval(sliders_context))

        if meshcat.GetButtonClicks(iris_button_name) > iris_button_clicks:
            iris_button_clicks = meshcat.GetButtonClicks(iris_button_name)
            # TODO(russt): Get the name from meshcat (#19666)
            region_name = "EETeleopRegion"
            region_num = 0
            while f"{region_name}{region_num}" in iris_regions.keys():
                region_num += 1
            meshcat.AddButton("Generating region (please wait)")
            GenerateRegion(
                f"{region_name}{region_num}", plant.GetPositions(plant_context)
            )
            meshcat.DeleteButton("Generating region (please wait)")
        elif X_WE.IsExactlyEqualTo(new_X_WE):
            time.sleep(1e-3)
            continue

        X_WE = new_X_WE
        q_ik = MyInverseKinematics(X_WE, plant, plant_context)
        print("q_ik: ", q_ik)
        if q_ik is not None:
            q = q_ik
            plant.SetPositions(plant_context, q)
            IrisIndicator(
                scene_graph,
                scene_graph_context,
                meshcat,
                iris_regions,
                p_WIndicator=[1, 1, 1],
            )
            diagram.ForcedPublish(context)

    meshcat.DeleteAddedControls()
    q = plant.GetPositions(plant_context)


EndEffectorTeleop()
# Out:
# Control the end-effector position/orientation with the sliders or the keyboard:
#   ┌───────┬┬───────┬┬───────┐      ┌───────┬┬───────┬┬───────┐
#   │   Q   ││   W   ││   E   │      │   U   ││   I   ││   O   │
#   │ roll- ││ pitch+││ roll+ │      │   z-  ││   y+  ││   z+  │
#   ├───────┼┼───────┼┼───────┤      ├───────┼┼───────┼┼───────┤
#   ├───────┼┼───────┼┼───────┤      ├───────┼┼───────┼┼───────┤
#   │   A   ││   S   ││   D   │      │   J   ││   K   ││   L   │
#   │  yaw- ││ pitch-││  yaw+ │      │   x-  ││   y-  ││   x+  │
#   └───────┴┴───────┴┴───────┘      └───────┴┴───────┴┴───────┘
#
# Press the 'Stop End Effector Teleop' button in Meshcat to continue or press 'Escape'
# q_ik:  [ 0.13518325  0.91436033  0.06280396 -1.28416194 -0.01415507  1.14949753
#   0.18653549  0.          0.        ]
# You found a counter-example!
# q_ik:  [ 0.13645296  0.8938469   0.06352944 -1.32477432 -0.01341933  1.12932496
#   0.18910805  0.          0.        ]
# You found a counter-example!
# q_ik:  [ 0.1351833   0.91343402  0.06275241 -1.28574638 -0.01414336  1.14683959
#   0.18661369  0.          0.        ]
# You found a counter-example!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 142
#     138     meshcat.DeleteAddedControls()
#     139     q = plant.GetPositions(plant_context)
# --> 142 EndEffectorTeleop()
#
# Cell In[20], line 120, in EndEffectorTeleop()
#     118     meshcat.DeleteButton("Generating region (please wait)")
#     119 elif X_WE.IsExactlyEqualTo(new_X_WE):
# --> 120     time.sleep(1e-3)
#     121     continue
#     123 X_WE = new_X_WE
#
# KeyboardInterrupt:

# %%
def JointTeleop():
    meshcat.Delete()
    meshcat.DeleteAddedControls()
    builder = DiagramBuilder()

    plant, scene_graph = AddMultibodyPlantSceneGraph(builder, time_step=0.0)
    LoadRobot(plant)
    plant.Finalize()

    sliders = builder.AddSystem(JointSliders(meshcat, plant))

    AddDefaultVisualization(builder, meshcat)
    diagram = builder.Build()
    context = diagram.CreateDefaultContext()
    plant_context = plant.GetMyMutableContextFromRoot(context)
    scene_graph_context = scene_graph.GetMyContextFromRoot(context)
    sliders_context = sliders.GetMyContextFromRoot(context)

    global q
    if len(q) == 0:
        q = plant.GetPositions(plant_context)
    sliders.SetPositions(q)

    # Implements a version of JointSliders.run() which can also watch for extra UI events.
    iris_button_name = "Compute new IRIS region"
    meshcat.AddButton(iris_button_name)
    iris_button_clicks = 0

    stop_button_name = "Stop Joint Teleop"
    print(
        f"Press the '{stop_button_name}' button in Meshcat to continue or press 'Escape'"
    )
    meshcat.AddButton(stop_button_name, "Escape")

    diagram.ForcedPublish(context)
    if not running_as_notebook:
        return

    while meshcat.GetButtonClicks(stop_button_name) < 1:
        # Check if the sliders have changed.
        old_positions = plant.GetPositions(plant_context)
        new_positions = sliders.get_output_port().Eval(sliders_context)

        if meshcat.GetButtonClicks(iris_button_name) > iris_button_clicks:
            iris_button_clicks = meshcat.GetButtonClicks(iris_button_name)
            # TODO(russt): Get the name from meshcat (#19666)
            region_name = "JointTeleopRegion"
            region_num = 0
            while f"{region_name}{region_num}" in iris_regions.keys():
                region_num += 1
            meshcat.AddButton("Generating region (please wait)")
            GenerateRegion(f"{region_name}{region_num}", new_positions)
            meshcat.DeleteButton("Generating region (please wait)")
        elif np.array_equal(new_positions, old_positions):
            time.sleep(1e-3)
            continue

        # Publish the new positions.
        plant.SetPositions(plant_context, new_positions)
        IrisIndicator(
            scene_graph,
            scene_graph_context,
            meshcat,
            iris_regions,
            p_WIndicator=[1, 1, 1],
        )
        diagram.ForcedPublish(context)

    meshcat.DeleteAddedControls()


JointTeleop()
# Out:
# Press the 'Stop Joint Teleop' button in Meshcat to continue or press 'Escape'

# %% [markdown]
# ## Visualize Conectivity

# %%
iris_regions = {}
iris_regions.update(LoadIrisRegionsYamlFile(iris_filename))
print(f"Loaded iris regions from {iris_filename}.")
# Out:
# Loaded iris regions from my_iris_object_welded.yaml.

# %%
def VisualizeConnectivity():
    graph = pydot.Dot("IRIS region connectivity")
    keys = list(iris_regions.keys())
    for k in keys:
        graph.add_node(pydot.Node(k))
    for i in range(len(keys)):
        v1 = iris_regions[keys[i]]
        for j in range(i + 1, len(keys)):
            v2 = iris_regions[keys[j]]
            if v1.IntersectsWith(v2):
                graph.add_edge(pydot.Edge(keys[i], keys[j], dir="both"))
    display(SVG(graph.create_svg()))

VisualizeConnectivity()

# %% [markdown]
# ## Plan trajectories with GCS Trajectory Optimization

# %%
from pydrake.geometry.optimization import GraphOfConvexSetsOptions, Point
from pydrake.planning import GcsTrajectoryOptimization

def get_bounded_velocity_lower_limit(plant):
    lim = plant.GetVelocityLowerLimits()
    # limit on rotation and prismatic joints
    return np.where(lim == -np.inf, -0.1, lim)

def get_bounded_velocity_upper_limit(plant):
    lim = plant.GetVelocityUpperLimits()
    # limit on rotation and prismatic joints
    return np.where(lim == np.inf, 0.1, lim)

def PublishPositionTrajectory(
    trajectory, root_context, plant, visualizer, time_step=1.0 / 33.0
):
    """
    Args:
        trajectory: A Trajectory instance.
    """
    plant_context = plant.GetMyContextFromRoot(root_context)
    visualizer_context = visualizer.GetMyContextFromRoot(root_context)

    visualizer.StartRecording(False)

    for t in np.append(
        np.arange(trajectory.start_time(), trajectory.end_time(), time_step),
        trajectory.end_time(),
    ):
        root_context.SetTime(t)
        plant.SetPositions(plant_context, trajectory.value(t))
        visualizer.ForcedPublish(visualizer_context)

    visualizer.StopRecording()
    visualizer.PublishRecording()


def GcsTrajOpt(q_start, q_goal):
    if not iris_regions:
        print(
            "No IRIS regions loaded. Make some IRIS regions then come back and try this again."
        )
        return
    assert len(q_start) == len(q_goal)
    assert len(q_start) == iris_regions[next(iter(iris_regions))].ambient_dimension()

    builder = DiagramBuilder()
    plant, scene_graph = AddMultibodyPlantSceneGraph(builder, time_step=0.0)
    LoadRobot(plant)
    fixIiwaGripperCollisionWithObjectInGripper(scene_graph, "thing_1", context = None)

    plant.Finalize()
    AddDefaultVisualization(builder, meshcat)
    diagram = builder.Build()

    gcs = GcsTrajectoryOptimization(len(q_start))
    # TODO(russt): AddRegions should take named regions.
    regions = gcs.AddRegions(list(iris_regions.values()), order=1)
    source = gcs.AddRegions([Point(q_start)], order=0)
    target = gcs.AddRegions([Point(q_goal)], order=0)
    gcs.AddEdges(source, regions)
    gcs.AddEdges(regions, target)
    gcs.AddTimeCost()
    print("Vel lim: ", get_bounded_velocity_lower_limit(plant))
    gcs.AddVelocityBounds(
        get_bounded_velocity_lower_limit(plant), get_bounded_velocity_upper_limit(plant)
    )

    options = GraphOfConvexSetsOptions()
    options.preprocessing = True
    options.max_rounded_paths = 5
    start_time = time.time()
    traj, result = gcs.SolvePath(source, target, options)
    print(type(traj))
    print(f"GCS solved in {time.time() - start_time} seconds")
    if not result.is_success():
        print("Could not find a feasible path from q_start to q_goal")
        return

    PublishPositionTrajectory(
        traj,
        diagram.CreateDefaultContext(),
        plant,
        diagram.GetSubsystemByName("meshcat_visualizer(illustration)"),
    )

# %%
# seeds["Seed 3"] = np.array([-0.46703898,  0.3326892 ,  0.59999243, 
#                              -1.53399322, -2.74964844,  0.28085682,
#                              -0.56446233, -0.05      ,  0.05      ])
assert (
    seeds
), "The examples here use the 'manually-specified seeds' from the section above. Please run that section first, or populate your own start and end configurations."
q_goal = np.array([0.13518325, 0.91436033,  0.06280396, -1.28416194,
                   -0.01415507,  1.14949753, 0.18653549, -0.01062164, 0.01063314])
GcsTrajOpt(seeds["Start MoveToDeliver"],  q_goal)
# GcsTrajOpt(seeds["Above Shelve"], seeds["Top Rack"])
# Out:
# INFO:drake:Solved GCS shortest path using Clp with convex_relaxation=true and preprocessing=true and rounding.
# INFO:drake:Found 1 unique paths, discarded 99 duplicate paths.
# INFO:drake:Finished 1 rounding solutions with Clp.
# 5
# Vel lim:  [-1.71042267 -1.71042267 -1.74532925 -2.26892803 -2.44346095 -3.14159265
#  -3.14159265 -0.1        -0.1       ]
# <class 'pydrake.trajectories.CompositeTrajectory'>
# GCS solved in 0.03484773635864258 seconds

# %%
seeds["End MoveToDeliver"]
# Out:
# array([-1.25664868, -0.42877396, -1.14081694, -1.17977965, -1.38902411,
#         0.75435786, -2.31282622, -0.025     ,  0.025     ])

# %%
seeds["Home Position"]
# Out:
# array([ 0.5 ,  0.6 ,  0.  , -1.75,  0.  ,  1.  ,  0.  , -0.05,  0.05])

# %%
if running_as_notebook:
    SaveIrisRegionsYamlFile(iris_filename, iris_regions)

# %%
if os.path.exists("/tmp/mosek.lic"):
    os.remove("/tmp/mosek.lic")
